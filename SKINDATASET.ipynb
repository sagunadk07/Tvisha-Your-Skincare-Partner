# %% [markdown]
# <a href="https://colab.research.google.com/github/sagunadk07/Tvisha-Your-Skincare-Partner/blob/main/SKINDATASET.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os

# %%
dataset_path = "/content/drive/MyDrive/Tvisha/dataset"

# %%
import os

os.listdir("/content/drive/MyDrive")
# Out:
# ['Classroom',
#  '8086_Program (1).gdoc',
#  '8086_Program.gdoc',
#  '1.Program to display Electronics an (2).gdoc',
#  '1.Program to display Electronics an (1).gdoc',
#  '1.Program to display Electronics an.gdoc',
#  'Untitled document (9).gdoc',
#  'Untitled document (8).gdoc',
#  'lab3.gdoc',
#  'smart budget tracker - Bar chart 1 (1).gsheet',
#  'smart budget tracker - Line chart 1.gsheet',
#  'smart budget tracker - Bar chart 1.gsheet',
#  'smart budget tracker.gdoc',
#  '20117982.pdf',
#  '20117982.gdoc',
#  'Weather Station - Column chart 1.gsheet',
#  'Weather Station - Line chart 1.gsheet',
#  'Weather Station - Bar chart 1 (2).gsheet',
#  'Weather Station - Bar chart 1 (1).gsheet',
#  'Untitled drawing - Bar chart 1 (2).gsheet',
#  'Untitled spreadsheet.gsheet',
#  'Untitled drawing - Bar chart 1 (1).gsheet',
#  'Untitled drawing - Bar chart 1.gsheet',
#  'Untitled drawing.gdraw',
#  'Weather Station - Bar chart 1.gsheet',
#  'Untitled document (7).gdoc',
#  'AI solving set ',
#  'Saved from Chrome',
#  'project',
#  'project.zip',
#  'Untitled document (6).gdoc',
#  'Untitled document (5).gdoc',
#  'Untitled document (4).gdoc',
#  'Untitled document (3).gdoc',
#  'Untitled document (2).gdoc',
#  'Ultimate Tech & Digital Literacy Quiz.pptx',
#  'Untitled document (1).gdoc',
#  'Final Round 3,PP.pptx',
#  'Untitled document.gdoc',
#  'Colab Notebooks',
#  'Skin Dataset',
#  'Untitled0.ipynb',
#  'Cleaned_Dataset']

# %%
dataset_path = "/content/drive/MyDrive/Skin Dataset"

# %%
os.listdir(dataset_path)
# Out:
# ['dataset-20260709T040035Z-3-001.zip']

# %%
import zipfile

zip_path = "/content/drive/MyDrive/Skin Dataset/dataset-20260709T040035Z-3-001.zip"
extract_path = "/content/dataset"

with zipfile.ZipFile(zip_path, 'r') as zip_ref:
    zip_ref.extractall(extract_path)

print("Dataset successfully extracted!")
# Out:
# Dataset successfully extracted!

# %%
import os

os.listdir("/content/dataset")
# Out:
# ['dataset']

# %%
import os

os.listdir("/content/dataset/dataset")
# Out:
# ['inflammatory acne',
#  'pores',
#  'non inflammatory acne white heads',
#  'wrinkles',
#  'dark spots',
#  'non inflammatory acne black heads',
#  'Redness',
#  'pigmentation']

# %%
dataset_path = "/content/dataset/dataset"

# %%
classes = os.listdir(dataset_path)

for cls in classes:
    folder = os.path.join(dataset_path, cls)
    total = len(os.listdir(folder))
    print(cls, ":", total)
# Out:
# inflammatory acne : 607
# pores : 600
# non inflammatory acne white heads : 300
# wrinkles : 600
# dark spots : 669
# non inflammatory acne black heads : 313
# Redness : 600
# pigmentation : 600

# %%
import matplotlib.pyplot as plt
from PIL import Image
import random
import os

classes = os.listdir(dataset_path)

for cls in classes:

    folder = os.path.join(dataset_path, cls)

    images = os.listdir(folder)

    sample_images = random.sample(images, 9)

    plt.figure(figsize=(8,8))

    for i, img_name in enumerate(sample_images):

        img = Image.open(os.path.join(folder, img_name))

        plt.subplot(3,3,i+1)

        plt.imshow(img)

        plt.axis("off")

    plt.suptitle(cls)

    plt.show()

# %%
from PIL import Image
import os

classes = os.listdir(dataset_path)

total_images = 0

for cls in classes:

    folder = os.path.join(dataset_path, cls)

    for img_name in os.listdir(folder):

        img_path = os.path.join(folder, img_name)

        try:
            img = Image.open(img_path)

            width, height = img.size

            print(img_name, "->", width, "x", height)

            total_images += 1

        except:
            print("Cannot open:", img_name)

print("Total Images:", total_images)
# Out:
# pigmentation_0_2996_jpeg.rf.0914c2f1eed75a2a8282e3dc3426e51a.jpg -> 2320 x 3088
# pigmentation_0_2696.jpeg -> 550 x 410
# maxresdefault (2) - Copy.jpg -> 1280 x 720
# pigmentation_0_1118_jpeg.rf.8771ad76421941092f802b98d21ded2c.jpg -> 355 x 266
# pigmentation_0_1405.jpeg -> 720 x 469
# R-21-_jpg.rf.27021373580ad3c12ab7a77cdfb04dc5.jpg -> 300 x 336
# acne146.png -> 258 x 195
# pigmentation_0_3597.jpeg -> 720 x 472
# pigmentation_0_479.jpeg -> 550 x 410
# R-33-_jpg.rf.cc16e99d61831304172bff50a1d9e581.jpg -> 1000 x 955
# acne155.png -> 282 x 300
# pigmentation_0_6769_jpeg.rf.4833610614827ccfb64bba6ad25e659b - Copy.jpg -> 2320 x 3088
# acne-cystic-111_jpg.rf.a5892123bf8fb25eae06d0f6696f6b9a - Copy.jpg -> 720 x 492
# R-5-_jpg.rf.9aa8355a2c02d6e997343101a3fdc6ee.jpg -> 560 x 644
# OIP (29) - Copy.jpg -> 615 x 409
# pigmentation_0_9715_jpeg.rf.987ff618b5341d27a7b655495427d50d.jpg -> 216 x 312
# OIP (9) - Copy.jpg -> 474 x 355
# acne139.png -> 258 x 195
# IMG_20190708_023210.jpg.7232dbb2bd7459bc1f8ae066423aa7a4 - Copy.jpg -> 3000 x 4000
# IMG_3554.JPG.f4bf444684be38571736983531eaafdf - Copy.jpg -> 520 x 520
# pigmentation_0_6345_jpeg.rf.e3b407c987b4fbc862541255ce300373 - Copy.jpg -> 275 x 183
# jko16nvn14061_png.rf.ecdba4fdf6a59877cb015508ae03b853 - Copy.jpg -> 960 x 821
# MDRUMF_Authentically_Spotty-1-1068x1431 - Copy.jpg -> 1068 x 1431
# acne175.png -> 1662 x 2046
# acne69.png -> 513 x 736
# pigmentation_0_1590_jpeg.rf.23192c39ec2db8b615ced43b81b23267.jpg -> 2320 x 3088
# pigmentation_0_3291.jpeg -> 306 x 226
# pigmentation_0_771.jpeg -> 216 x 312
# R-36-_jpg.rf.4c4a7e227d41d76c1b18a108e3964175.jpg -> 640 x 705
# acne-pustular-40_jpg.rf.3b4bb40099ef6979943c41b37875b32b - Copy.jpg -> 482 x 720
# acne120.png -> 640 x 853
# Rosacea-2-Dr-Ben-Barankin-4-e1417628132564-400x302_jpg.rf.d65369f04a25deac372977491435814c.jpg -> 400 x 302
# istockphoto-849986310-170667a - Copy.jpg -> 509 x 339
# acne-excoriated-18.jpg -> 479 x 720
# acne-pustulesandpapules-1593x2048_jpg.rf.fe655e97361e59659409d1dfd80c8ed9 - Copy.jpg -> 1593 x 2048
# 1.png -> 373 x 430
# acne-pustular-55 - Copy.jpg -> 469 x 720
# acne99.png -> 3085 x 1327
# pigmentation_0_7008_jpeg.rf.559193009bf1e7f60c30a97e651df5af - Copy.jpg -> 467 x 720
# gallery_438857_14052_2182_jpg.rf.2aa9066e3755f9f84e58570ce0818c62 - Copy.jpg -> 720 x 960
# acne20.png -> 275 x 183
# image_jpg.rf.2ec0ead6a5f9b2c64bb7bd5f11ae8fda - Copy.jpg -> 2000 x 1050
# acne35.png -> 673 x 535
# OIP (7) - Copy.jpg -> 474 x 355
# pigmentation_0_8122_jpeg.rf.51a4a099a19fbb8d06fdac52aa993c9e.jpg -> 720 x 472
# acne118.png -> 720 x 405
# pigmentation_0_7745_jpeg.rf.61db52f9eeaff69f134b7abf22fd2b14 - Copy.jpg -> 720 x 477
# R (39).jpg -> 1500 x 1985
# resize_jpg.rf.ac870eff6724a3ef12925b7ee666b245.jpg -> 648 x 833
# pigmentation_0_3064_jpeg.rf.5ebdb01818847725fa7e27d62c24b91d.jpg -> 600 x 400
# OIP (28) - Copy.jpg -> 474 x 283
# red-spots-on-skin-facial-rashes_jpg.rf.7a496671a1f18b5dd5da8db4e88614c0.jpg -> 640 x 424
# pigmentation_0_119.jpeg -> 306 x 226
# pigmentation_0_7373_jpeg.rf.934572785448a9cc6b1b904dc179239f - Copy.jpg -> 720 x 477
# pigmentation_0_178.jpeg -> 474 x 330
# pigmentation_0_3713_jpeg.rf.5a9df7bae2414fb9cbc7e39ab2bd28cf - Copy.jpg -> 720 x 471
# Pustule-21-_JPG_jpg.rf.d5a1f46d7a28ef161d4836471facc390.jpg -> 640 x 640
# pigmentation_0_3903_jpeg.rf.4cc4cfe7ead57d77d4107100ee3533eb.jpg -> 275 x 183
# acne46.png -> 722 x 406
# gallery_59843_6647_31633 - Copy.jpg -> 1000 x 539
# acne-pustular-47_jpg.rf.5e17857e25b4a8640643c98ef00d8327 - Copy.jpg -> 720 x 471
# pigmentation_0_3481.jpeg -> 550 x 410
# pigmentation_0_6791_jpeg.rf.f8df4db848ac26ba258969e0e6af4e18.jpg -> 615 x 923
# acne50.png -> 960 x 1280
# acne-pustular-24 - Copy.jpg -> 720 x 480
# R-20-_jpg.rf.2871e57b095225dff4de33fad1d135f6.jpg -> 300 x 180
# pigmentation_0_2576.jpeg -> 720 x 480
# acne-excoriated-11 - Copy.jpg -> 720 x 472
# R-29-_jpg.rf.d8e37e8e838bdbe4e4493d41eba9251d.jpg -> 800 x 398
# pigmentation_0_3069.jpeg -> 615 x 923
# Pustule-19-_JPG_jpg.rf.45e462adf9a0436428abd4d66ab10faf.jpg -> 640 x 640
# acne-cystic-121 - Copy.jpg -> 720 x 475
# acne143.png -> 500 x 500
# pigmentation_0_211.jpeg -> 474 x 330
# OIP (14) - Copy.jpg -> 276 x 276
# pigmentation_0_7896_jpeg.rf.50bdb1780c339c92e7d93812094cda64 - Copy.jpg -> 474 x 330
# pigmentation_0_8613_jpeg.rf.045b02f56a8a13d153949148c2e0ec2f.jpg -> 1024 x 682
# fungal-acne (1) - Copy.jpg -> 1600 x 1064
# acne21.png -> 275 x 183
# acne28.png -> 1024 x 575
# pigmentation_0_6650_jpeg.rf.378ce4af13cf09f2fa35fd33488efa02.jpg -> 720 x 475
# pigmentation_0_6672_jpeg.rf.941d5bc237abb74e11ca55194cce9fdf.jpg -> 550 x 410
# rosacea-steroid-8_jpg.rf.759a0f8882b5ee9e0d2f21d2fcf6a18a.jpg -> 720 x 472
# pigmentation_0_7281_jpeg.rf.3d954174c7982f07c77882dd0b8c5980.jpg -> 720 x 472
# R (24).jpg -> 480 x 480
# pigmentation_0_2287.jpeg -> 275 x 183
# pigmentation_0_2596.jpeg -> 600 x 400
# pigmentation_0_3018.jpeg -> 720 x 480
# acne-cystic-28.jpg -> 720 x 472
# pigmentation_0_2538.jpeg -> 615 x 923
# pigmentation_0_903.jpeg -> 720 x 540
# 29.png -> 600 x 579
# R (19).jpg -> 976 x 549
# acne181.png -> 350 x 234
# gallery_483742_14314_59312_jpeg.rf.ecb1ea2c84de33ef4c2ce836e1150080 - Copy.jpg -> 750 x 1000
# acne-pustular-55_jpg.rf.4fd1db14597ab8a9d6930450f92c886b - Copy.jpg -> 469 x 720
# IMG_3366.JPG.799f3d13a535a94016ba39c390b09efa - Copy.jpg -> 960 x 1280
# pigmentation_0_3893.jpeg -> 720 x 540
# acne68.png -> 800 x 601
# acne101.png -> 780 x 440
# acne-cystic-19_jpg.rf.247189a7221896c019f8fb5008f48702 - Copy.jpg -> 720 x 480
# Thirteen-ways-to-remove-acne-scars-quickly-in-one-day-1-_jpg.rf.30f3db7d62cb8b931ad3cb11d1023952.jpg -> 1600 x 1067
# pigmentation_0_8668_jpeg.rf.e3cfcbe2c3adada40eedac88034792fb.jpg -> 800 x 601
# pigmentation_0_8014_jpeg.rf.8b89f4c7a8ad2ce2b49b5722d70a83e2 - Copy.jpg -> 720 x 587
# pigmentation_0_4345_jpeg.rf.94352656f2cd311e3a344dd07ad867e9.jpg -> 720 x 485
# acne-cystic-32.jpg -> 720 x 472
# acne-cystic-126_jpg.rf.c7d932d29ed390cb2e7c5b3f1f514592 - Copy.jpg -> 720 x 465
# papular_acne_-92-_jpg.rf.77767b3d6719febc11d7122999fc71a6 - Copy.jpg -> 640 x 640
# post-370921-0-39350300-1389608977.jpg -> 750 x 500
# pigmentation_0_6208_jpeg.rf.a187e2ad45010ba66f631f976d40c527.jpg -> 720 x 477
# acne128.png -> 663 x 515
# pigmentation_0_3713.jpeg -> 720 x 471
# acne195.png -> 1170 x 658
# pigmentation_0_6270_jpeg.rf.0dc4d079c04604a45fcab0875ab559c9 - Copy.jpg -> 216 x 312
# pigmentation_0_7042_jpeg.rf.0f48773bb543e9b442cdc086b664a923.jpg -> 475 x 573
# acne103.png -> 300 x 170
# pustular_acne_-339-_jpg.rf.15825c4ac6a444be48f46ff0b923defc.jpg -> 640 x 640
# pigmentation_0_1805_jpeg.rf.6845d62f96b905005e0a835cbd655bd6.jpg -> 550 x 410
# pigmentation_0_3893_jpeg.rf.301860eb8a86f0f17e5348921dcaa7bd - Copy.jpg -> 720 x 540
# papular_acne_-91-_jpg.rf.c52a6d66f1d74834ea76550c1c731cc2 - Copy.jpg -> 640 x 640
# R (36).jpg -> 640 x 705
# pigmentation_0_8649_jpeg.rf.d9901a4aa8b54e4a21f406fba4987790.jpg -> 481 x 295
# rosacea-36.jpg -> 720 x 472
# acne-cystic-25.jpg -> 720 x 480
# R-16-_jpg.rf.f016ec9362526009adcb6012fe645cf6.jpg -> 1000 x 724
# acne-pustular-51 - Copy.jpg -> 720 x 470
# C0384485-Acne_vulgaris - Copy.jpg -> 800 x 613
# pigmentation_0_6858_jpeg.rf.be119b369f382f4f97e2e99a4c8cf5f6 - Copy.jpg -> 720 x 481
# pigmentation_0_3040.jpeg -> 481 x 295
# pigmentation_0_2292.jpeg -> 467 x 720
# acne30.png -> 612 x 459
# pigmentation_0_2967.jpeg -> 800 x 601
# acne-pustular-58 - Copy.jpg -> 649 x 720
# acne02bf-21 - Copy (2).jpg -> 481 x 295
# pigmentation_0_2384.jpeg -> 720 x 540
# pigmentation_0_1017.jpeg -> 720 x 472
# acne-pustular-8 - Copy.jpg -> 720 x 472
# acne-pustular-45 - Copy.jpg -> 720 x 471
# large-IMG_8887-JPG-be05af23e48fb382e5811e2f915ddf90_jpg.rf.672b9718f6fed67ea530f9e25aa9065a - Copy.jpg -> 900 x 1200
# acne158.png -> 1280 x 720
# pigmentation_0_6264_jpeg.rf.389dcd7c7a92946ad0bc3e0becc28146 - Copy.jpg -> 720 x 485
# acne61.png -> 240 x 194
# pigmentation_0_2996.jpeg -> 2320 x 3088
# R (28).jpg -> 520 x 216
# acne194.png -> 2320 x 3088
# acne-visual-dictionary-s11-severe-nodulocystic-acne_jpg.rf.63effb7a3e223931b74dd8912ddcf453 - Copy.jpg -> 493 x 335
# acne-cystic-117_jpg.rf.684d861adf5d8910e930de62d298ab4b - Copy.jpg -> 482 x 720
# acne-pustular-72 - Copy.jpg -> 720 x 473
# papular_acne_-90-_jpg.rf.b190135eed655adb199fac8b55f2cd44 - Copy.jpg -> 640 x 640
# pigmentation_0_7745_jpeg.rf.61db52f9eeaff69f134b7abf22fd2b14.jpg -> 720 x 477
# pustular_acne_-6-_jpg.rf.b2f27f68e0443b0526688472cc0e796b.jpg -> 640 x 640
# acne-pustular-74_jpg.rf.cb8cc07ac71a3ac0b2334ad2e83ee8be - Copy.jpg -> 720 x 479
# M2500052-Acne_rosacea - Copy.jpg -> 800 x 543
# papular_acne_-37-_jpg.rf.f06b3389a161507b34f129e190231433 - Copy.jpg -> 640 x 640
# acne-pustular-42_jpg.rf.286ca20de892f1ed3b3e34396336d2b9 - Copy.jpg -> 720 x 474
# How-I-Cleared-My-Acne2_png.rf.16defb652ba92843b570020c8217d2dc - Copy.jpg -> 720 x 810
# papular_acne_-100-_jpg.rf.af2b7be95c7ab0915840af6c44266904 - Copy.jpg -> 640 x 640
# pigmentation_0_1229.jpeg -> 800 x 601
# pigmentation_0_8048_jpeg.rf.37844ec2ebb5e21842b96fa23bf05729.jpg -> 720 x 480
# pigmentation_0_2101.jpeg -> 476 x 461
# pigmentation_0_3040_jpeg.rf.2af167b837b6e6f3b2e3e3f47556f45c.jpg -> 481 x 295
# pigmentation_0_7896_jpeg.rf.50bdb1780c339c92e7d93812094cda64.jpg -> 474 x 330
# pigmentation_0_1247.jpeg -> 720 x 475
# Acne-Before4_png.rf.b27ecf3fe694046a4c1e6ce85c33afeb - Copy.jpg -> 600 x 579
# pustular_acne_-338-_jpg.rf.a1b2e3f705348b19d167779006d8c503.jpg -> 640 x 640
# acne151.png -> 480 x 360
# acne11 - Copy.jpg -> 413 x 449
# acne-pustulesandpapules-1593x2048 - Copy.jpg -> 1593 x 2048
# R-18-_jpg.rf.452c18e44a55421a1e06229d2b605f42.jpg -> 700 x 446
# acne135.png -> 2448 x 3264
# pigmentation_0_5928_jpeg.rf.24002d385fdd51e714a2b4054bdc1816.jpg -> 467 x 720
# levle3_129_jpg.rf.3c5b02174aea44c5ea48b21a08c35abb - Copy.jpg -> 150 x 150
# acne-pustular-33 - Copy.jpg -> 720 x 486
# how-to-get-rid-of-acne.png -> 1570 x 884
# acne-pustular-38 - Copy.jpg -> 720 x 461
# pigmentation_0_3648.jpeg -> 615 x 923
# pigmentation_0_352.jpeg -> 720 x 485
# pvhhnuftvjp31.png -> 960 x 960
# acne147.png -> 560 x 800
# pigmentation_0_8508_jpeg.rf.0373f20afbccfbfb99b087a711b65e4e.jpg -> 720 x 540
# acne-cystic-20.jpg -> 720 x 472
# rosacea-30.jpg -> 720 x 472
# pigmentation_0_7728_jpeg.rf.1eeaa1c446d6ad073c4592ac7a609276.jpg -> 600 x 400
# OIP-13-_jpg.rf.5068b4a25bf3d82246d957a09c5e3d75 - Copy.jpg -> 300 x 204
# pigmentation_0_6945_jpeg.rf.adda923208d71563304aa6136446c74e - Copy.jpg -> 550 x 410
# pigmentation_0_2784.jpeg -> 720 x 472
# pigmentation_0_3903_jpeg.rf.4cc4cfe7ead57d77d4107100ee3533eb - Copy.jpg -> 275 x 183
# rosacea-1_jpg.rf.6a070824b9f75a9a53a77e78edee823d.jpg -> 720 x 480
# R (23).jpg -> 700 x 446
# acne200.png -> 300 x 300
# acne-cystic-31.jpg -> 472 x 720
# IMG_0043.JPG.70f9dc7d17dcdf8dbb055d4013e94831 - Copy.jpg -> 1932 x 2576
# pigmentation_0_4825_jpeg.rf.897bdf93988ae3ab3d482800a239031a.jpg -> 306 x 226
# pigmentation_0_2061_jpeg.rf.be9d4d6d4926bde94f8f8abb13f3e4a2.jpg -> 800 x 601
# pigmentation_0_3020.jpeg -> 720 x 587
# acne-cystic-127_jpg.rf.d2db428f1f47d620334805a13b72bd5a - Copy.jpg -> 720 x 474
# R-30-_jpg.rf.1569eb2eacb43fb6a925bb01d4647c8d.jpg -> 350 x 256
# pigmentation_0_1051_jpeg.rf.21897ee018cdc0af1f778391b9274948.jpg -> 960 x 1280
# uq3mypax59u51_png.rf.ff143e5e27974140e20c497384735d48.jpg -> 640 x 853
# pigmentation_0_1838.jpeg -> 600 x 400
# acne159.png -> 360 x 240
# acne183.png -> 286 x 176
# pigmentation_0_1083_jpeg.rf.4d7eba1976a5ff5d01092ebac082914e.jpg -> 1024 x 682
# R-6-_jpg.rf.24667efe013c07574cf00c4a61ccc1a4.jpg -> 600 x 615
# rosacea-25.jpg -> 472 x 720
# acne-pustular-25 - Copy.jpg -> 720 x 480
# pigmentation_0_7231_jpeg.rf.eedb9e404598f3729181acc93eb0c41e - Copy.jpg -> 720 x 464
# acne45.png -> 266 x 189
# resize-1-_jpg.rf.672af4e834300dd83a38c0bbc7a38404.jpg -> 648 x 377
# acne140.png -> 1155 x 648
# pigmentation_0_2567.jpeg -> 800 x 601
# Pustule-27-_jpg.rf.f54091ec550aea7b29f18874ebc6bd90.jpg -> 640 x 640
# looking-at-acne-skin-800x534 - Copy.jpg -> 800 x 534
# Pustule-23-_JPG_jpg.rf.4e1e895ebf7835e83581a0d18f718267.jpg -> 640 x 640
# R (21).jpg -> 300 x 336
# acne_vulgaris_png.rf.5712dc4c4ee95c3451d668fa6a264db7 - Copy.jpg -> 592 x 480
# OIP (15) - Copy.jpg -> 276 x 315
# pigmentation_0_7267_jpeg.rf.ab7c0ba9c67bd4b04965520f2b686124.jpg -> 481 x 295
# R-22-_jpg.rf.507b3a22e3682cae7332c2ec4e963283.jpg -> 333 x 482
# Bells-Palsy-1_jpg.rf.5a73d1fea143325f493eecaa8308522e - Copy.jpg -> 683 x 513
# pigmentation_0_2298.jpeg -> 600 x 400
# papular_acne_-68-_jpg.rf.d021af3549f8e91011d05642399c0b6d.jpg -> 640 x 640
# rosacea-27.jpg -> 638 x 438
# acne149.png -> 1000 x 750
# pigmentation_0_263.jpeg -> 720 x 487
# pigmentation_0_3064.jpeg -> 600 x 400
# pigmentation_0_796.jpeg -> 306 x 226
# 2 (12).jpeg -> 275 x 183
# IMG_3612.JPG.725c4d39a5a52639dde2be8be7b05adc - Copy.jpg -> 2576 x 1932
# Pustule-16-_JPG_jpg.rf.fc49b3d6bbd4cb4efce450ff2e8d0314.jpg -> 640 x 640
# R (43).jpg -> 360 x 345
# pigmentation_0_7920_jpeg.rf.73e1327525dc24bb1f827cd4d38dfa83.jpg -> 476 x 461
# pigmentation_0_75.jpeg -> 720 x 480
# pigmentation_0_7904_jpeg.rf.b7ece2b8640ba2650ee0ea73333340dd.jpg -> 615 x 923
# Before - Copy.jpg -> 585 x 390
# acne-cystic-31_jpg.rf.7c31885ff40c7389a40f592b024133e6.jpg -> 472 x 720
# tumblr_npa77rk2UW1r8l3gko1_400 (1).png -> 332 x 373
# pigmentation_0_3081.jpeg -> 475 x 573
# papular_acne_-98-_jpg.rf.3a5df38fe3d26899eb44c81d9e1d6ebb - Copy.jpg -> 640 x 640
# acne121.png -> 640 x 853
# acne191.png -> 615 x 409
# R (5).jpg -> 560 x 644
# acne2.png -> 704 x 528
# pigmentation_0_8916_jpeg.rf.81941427b65c548c4f19e3cf347dfe25 - Copy.jpg -> 306 x 226
# R-38-_jpg.rf.edf844c12bb1771e23a7b9d1c033cadc.jpg -> 1200 x 1600
# pigmentation_0_2009_jpeg.rf.edcfcfc1efa8aacb458098caef5fe08f.jpg -> 634 x 629
# pigmentation_0_362.jpeg -> 734 x 481
# R-24-_jpg.rf.f8365eec22674b7fe46c3168f2e47bec.jpg -> 480 x 480
# pigmentation_0_921.jpeg -> 720 x 477
# acne-cystic-130 - Copy.jpg -> 720 x 472
# acne-face-2-14__ProtectWyJQcm90ZWN0Il0_FocusFillWzI5NCwyMjIsIngiLDFd_jpg.rf.17a193e69e04ee2582e9e2f52d6bf3f9.jpg -> 150 x 150
# IMG_2145-1 - Copy.jpg -> 760 x 519
# R-42-_jpg.rf.ed26045daddfedcd4d824092571aa75d.jpg -> 410 x 446
# maxresdefault (5) - Copy.jpg -> 1280 x 720
# pigmentation_0_5871_jpeg.rf.407619ebe84afd09ee243f13614618a9.jpg -> 720 x 540
# pigmentation_0_1893.jpeg -> 720 x 487
# pigmentation_0_2807.jpeg -> 474 x 330
# acne190.png -> 800 x 600
# pigmentation_0_2006.jpeg -> 720 x 475
# acne-pustular-68_jpg.rf.e3fed101d8f5d8eea19d51b48f371238 - Copy.jpg -> 473 x 720
# acne156.png -> 201 x 300
# acne8.png -> 482 x 364
# pigmentation_0_8793_jpeg.rf.7f77725894562ad354401de80af9a955.jpg -> 467 x 720
# pigmentation_0_7759_jpeg.rf.b23b4b5c7523c9f57e5e116dbe04c617 - Copy.jpg -> 720 x 587
# OIP-15-_jpg.rf.f78e7ea54c22107a214fc68ff216ab21 - Copy.jpg -> 276 x 315
# pigmentation_0_515.jpeg -> 474 x 330
# acne9.png -> 1440 x 810
# unnamed-1-_jpg.rf.6ccbb269f86fc1ae4cea79b59895ba49.jpg -> 528 x 396
# rosacea-88_jpg.rf.894bff7a9ad57be3a767a67900021dd2.jpg -> 475 x 720
# pigmentation_0_6712_jpeg.rf.1eaed5aee4f586e2f06b8e1025291944.jpg -> 413 x 449
# pigmentation_0_1209_jpeg.rf.c7b8d8e6457ca5807d6384e157360966.jpg -> 800 x 601
# pigmentation_0_8087_jpeg.rf.4819b5aefbc1cb7018db98f4b2628506.jpg -> 480 x 252
# acne152.png -> 480 x 359
# acne153.png -> 258 x 195
# acne4.png -> 4096 x 2730
# pigmentation_0_1962.jpeg -> 720 x 487
# maxresdefault - Copy.jpg -> 1280 x 720
# pigmentation_0_5944_jpeg.rf.18e5fc2d8324d2c2e379e94daad6a061.jpg -> 467 x 720
# R-43-_jpg.rf.592984bbbbb588e2df8227279bf1b745.jpg -> 360 x 345
# acne58.png -> 600 x 450
# pigmentation_0_1288.jpeg -> 475 x 573
# pigmentation_0_4288_jpeg.rf.df36e9a96d1aabbc911891cd22143a2c.jpg -> 600 x 400
# acne-face-2-9__ProtectWyJQcm90ZWN0Il0_FocusFillWzI5NCwyMjIsInkiLDg1XQ_jpg.rf.f01560d3ed05415f93c4d29c3adf6e0f.jpg -> 150 x 150
# acne-cystic-29_jpg.rf.79649a39ae24b909c926069f5f34ae7f.jpg -> 480 x 720
# pigmentation_0_7206_jpeg.rf.c8cacc3391bd1162c2d839f59e706020 - Copy.jpg -> 720 x 472
# pigmentation_0_1337.jpeg -> 720 x 471
# acne-pustular-17 - Copy.jpg -> 720 x 480
# pigmentation_0_1468.jpeg -> 720 x 540
# R (3).jpg -> 720 x 960
# acne-pustular-70_jpg.rf.5d6cb294b452f7f0beb29f93d8fd8acb - Copy.jpg -> 720 x 472
# acne-pustular-63_jpg.rf.c6bccbf8f91814ed66fcdaece8b6700f - Copy.jpg -> 720 x 617
# pigmentation_0_2753.jpeg -> 720 x 487
# OIP (11) - Copy.jpg -> 294 x 222
# acne-cystic-19_jpg.rf.247189a7221896c019f8fb5008f48702.jpg -> 720 x 480
# pigmentation_0_9431_jpeg.rf.0b66fc02af5e8581e6f435039cf063a6.jpg -> 800 x 601
# R-1-_png.rf.045b3b5a870c4fc5fff40f3b9719f5f8.jpg -> 300 x 149
# acne53.png -> 1000 x 750
# EWzV7k5Gy-5yjsFf8-Y5kQ_m-1-_jpg.rf.5b67db1953e7d7e65ce7741d4a673f63 - Copy.jpg -> 235 x 240
# pigmentation_0_7281_jpeg.rf.3d954174c7982f07c77882dd0b8c5980 - Copy.jpg -> 720 x 472
# Papule11_JPG_jpg.rf.847787ce6bfd8e81d5811a7bad74477f.jpg -> 640 x 640
# acne-cystic-20 - Copy.jpg -> 720 x 472
# acne62.png -> 380 x 310
# acne41.png -> 6900 x 4600
# pigmentation_0_2150.jpeg -> 632 x 592
# pigmentation_0_2002.jpeg -> 272 x 185
# pigmentation_0_2886_jpeg.rf.848f6b8a042ed74eb169cfb10a5dec72.jpg -> 467 x 720
# pigmentation_0_179.jpeg -> 476 x 461
# rosacea-88.jpg -> 475 x 720
# pigmentation_0_3386.jpeg -> 720 x 477
# pigmentation_0_3317.jpeg -> 650 x 350
# acne125.png -> 602 x 452
# pigmentation_0_2321.jpeg -> 720 x 472
# pigmentation_0_8916_jpeg.rf.81941427b65c548c4f19e3cf347dfe25.jpg -> 306 x 226
# red-spots-on-skin-facial-rashes.jpg -> 640 x 424
# rosacea-29.jpg -> 720 x 472
# perioral-dermatitis-90_jpg.rf.d6b47818db18998907f85495604e3fad - Copy.jpg -> 720 x 461
# acne-cystic-21.jpg -> 720 x 480
# R (38).jpg -> 1200 x 1600
# pigmentation_0_4527_jpeg.rf.64a1eb56b8d021d4628c205c1adfc4d0.jpg -> 720 x 472
# acne119.png -> 960 x 1280
# pigmentation_0_3379.jpeg -> 275 x 183
# acne-excoriated-8 - Copy.jpg -> 720 x 472
# rosacea-39.jpg -> 472 x 720
# R-35-_jpg.rf.ced01274afc9773ede7251ec83543ff6.jpg -> 976 x 900
# R (42).jpg -> 410 x 446
# acne-excoriated-4 - Copy.jpg -> 720 x 472
# acne37.png -> 4096 x 2730
# levle1_15_jpg.rf.14aa63cc6a6c36d80ff77444129723d3 - Copy.jpg -> 150 x 150
# jko16nvn14061.png -> 960 x 821
# Acne-cyst-1-150x150.jpg -> 150 x 150
# pigmentation_0_8194_jpeg.rf.c95066d818e8b45ae205b72c3ab15ecf.jpg -> 550 x 410
# acne59.png -> 640 x 640
# acne-excoriated-3_jpg.rf.d04196730fc7652e96aeb068aff81759 - Copy.jpg -> 472 x 720
# acne-excoriated-29.jpg -> 720 x 477
# pigmentation_0_7428_jpeg.rf.dd7bc040b93f356c616287c806072103.jpg -> 720 x 587
# pigmentation_0_7447_jpeg.rf.973667b8b63e9e8178d372823c4df2d0.jpg -> 550 x 410
# mkb737oqpro51_jpg.rf.57e8d459f0fb2300e7ef406cb866c700 - Copy.jpg -> 3088 x 2320
# acne-pustular-69 - Copy.jpg -> 720 x 474
# pigmentation_0_7184_jpeg.rf.770baad26effd8ab165566b95ea41ba3.jpg -> 720 x 487
# acne-pustular-67 - Copy.jpg -> 720 x 474
# R-1-_jpg.rf.61b2485acf85c94ec3bb51ebb6c33a85.jpg -> 1600 x 1200
# pigmentation_0_9585_jpeg.rf.0586370995225435c0c5affd489a9da3.jpg -> 720 x 481
# acne-pustular-66_jpg.rf.1c9ea443cb0647096eb2a263380b1c1e - Copy.jpg -> 477 x 720
# image.jpg.074f5bf4398673d5345e34a77d26f2f8 - Copy.jpg -> 960 x 1280
# pvhhnuftvjp31(1).png -> 960 x 960
# acne180.png -> 600 x 450
# acne-pustular-54_jpg.rf.fac1af3b3a8cf1d0af0deef7261fee30 - Copy.jpg -> 720 x 474
# uq3mypax59u51(1).png -> 640 x 853
# pigmentation_0_3020_jpeg.rf.a3083f8ad2e261363f9b69b2a624858a.jpg -> 720 x 587
# R-19-_jpg.rf.6c675156c942b48bef041f06a20045d6.jpg -> 976 x 549
# pigmentation_0_797.jpeg -> 800 x 601
# OIP (1) - Copy.jpg -> 474 x 632
# pigmentation_0_949_jpeg.rf.ed048886e9220c83e4283e4e97d2817f.jpg -> 306 x 226
# acne-cystic-107_jpg.rf.e0526e012e8e76b95bf78e2ae7ba5388 - Copy.jpg -> 720 x 465
# acne187.png -> 640 x 480
# acne-pustular-65 - Copy.jpg -> 720 x 477
# acne160.png -> 722 x 406
# pigmentation_0_1135.jpeg -> 720 x 485
# pigmentation_0_9821_jpeg.rf.35eb2e07982f02490f477d2ad2fac4c8.jpg -> 800 x 601
# pigmentation_0_6418_jpeg.rf.1059051759f0254f770bf59db258f4ca - Copy.jpg -> 600 x 400
# acne107.png -> 533 x 800
# 362f516bc2be4f01904fb2950eb700f411.png -> 373 x 430
# acne44.png -> 1024 x 683
# resize (1).jpg -> 648 x 377
# C0384483-Acne_vulgaris - Copy.jpg -> 800 x 560
# acne184.png -> 400 x 533
# OIP-24-_jpg.rf.3bfd8bb6ebb51eb97c42fbce5d704e9a - Copy.jpg -> 474 x 632
# Acne_rosacea_051.jpeg -> 442 x 361
# pigmentation_0_2441.jpeg -> 467 x 720
# acne-treatment-02 - Copy.jpg -> 700 x 700
# levle2_141_jpg.rf.cc601efd980b56b530a2d463383085e1 - Copy.jpg -> 150 x 150
# pigmentation_0_3667.jpeg -> 720 x 477
# cystic-acne_G_694069050_jpg.rf.e4a52ff80f9ae6037eab2127ada3ecf5 - Copy.jpg -> 2000 x 1333
# Rosacea-2-Dr.-Ben-Barankin-4-e1417628132564-400x302.jpg -> 400 x 302
# acne-pustular-60 - Copy.jpg -> 720 x 658
# R.jpg -> 1137 x 1363
# pigmentation_0_367.jpeg -> 467 x 720
# pigmentation_0_1170.jpeg -> 960 x 1280
# acne-excoriated-27.jpg -> 720 x 477
# acne-cystic-26 - Copy.jpg -> 720 x 480
# pigmentation_0_8654_jpeg.rf.23e3c8ed7ea26140517f4d4070775abc.jpg -> 600 x 400
# rosacea-25_jpg.rf.4b9472bef9c41745cb5783c808d92f41.jpg -> 472 x 720
# acne72.png -> 975 x 730
# gallery_164926_12280_652062 - Copy.jpg -> 1000 x 750
# R-4-_jpg.rf.e20ab58061a00a1b72556765a5822db6.jpg -> 1600 x 1200
# acne-cystic-32_jpg.rf.f3e921571a3f6f797d559093c56d0e50 - Copy.jpg -> 720 x 472
# pigmentation_0_1450_jpeg.rf.df95e79a3a490bb02aa1be79322361c0 - Copy.jpg -> 960 x 1280
# acne189.png -> 187 x 270
# acne-face-29__ProtectWyJQcm90ZWN0Il0_FocusFillWzI5NCwyMjIsIngiLDFd_jpg.rf.3ac073e96073450911d9c339273b22a8.jpg -> 150 x 150
# pigmentation_0_2397.jpeg -> 600 x 400
# uq3mypax59u51.png -> 640 x 853
# acne185.png -> 1206 x 2208
# acne-pustular-15_jpg.rf.47bb99983ca035e59f4d7f5353919b37 - Copy.jpg -> 720 x 472
# pigmentation_0_895.jpeg -> 275 x 183
# pigmentation_0_3062.jpeg -> 720 x 475
# pigmentation_0_8014_jpeg.rf.8b89f4c7a8ad2ce2b49b5722d70a83e2.jpg -> 720 x 587
# acne131.png -> 1080 x 1069
# pigmentation_0_147.jpeg -> 600 x 400
# pigmentation_0_6569_jpeg.rf.f00c0ec38d237031c8c6612025a2f22c - Copy.jpg -> 600 x 400
# pc438phx95i41 - Copy.jpg -> 2048 x 1574
# acne63.png -> 205 x 246
# pigmentation_0_3669.jpeg -> 720 x 485
# pigmentation_0_3706.jpeg -> 720 x 477
# acne129.png -> 2988 x 5312
# acne-cystic-113_jpg.rf.368dac8f03c7b6d652e5295bd1ff927b - Copy.jpg -> 720 x 478
# acne-cystic-129 - Copy.jpg -> 720 x 467
# 32-1536x615.png -> 756 x 615
# pigmentation_0_7920_jpeg.rf.73e1327525dc24bb1f827cd4d38dfa83 - Copy.jpg -> 476 x 461
# pigmentation_0_6648_jpeg.rf.95db317fdc08061d8e303ed13f5eacde.jpg -> 600 x 400
# acne10.png -> 590 x 436
# pigmentation_0_3819.jpeg -> 475 x 573
# acne178.png -> 2320 x 3088
# pigmentation_0_7184_jpeg.rf.770baad26effd8ab165566b95ea41ba3 - Copy.jpg -> 720 x 487
# IMG_8544-thumb-JPG-faf77397f165101fbe28d89642ac2fe3_jpg.rf.fdaa20822f424f9a0f16fc367bb02ede - Copy.jpg -> 563 x 750
# acne157.png -> 200 x 150
# u06kz58buhi11.png -> 640 x 853
# acne-cystic-118 - Copy.jpg -> 471 x 720
# maxresdefault-4-_jpg.rf.a195630447b90e1498416b981e288812 - Copy.jpg -> 1280 x 720
# pigmentation_0_2217.jpeg -> 275 x 183
# acne176.png -> 1932 x 2576
# pigmentation_0_8233_jpeg.rf.df21208b59be278f8dd6efc9b099d5a5.jpg -> 720 x 485
# R (7).jpg -> 720 x 480
# acne-scarring-300x300 - Copy.jpg -> 300 x 300
# pigmentation_0_1170_jpeg.rf.e758f1af33b3313fb22d560cd4159ceb.jpg -> 960 x 1280
# 93_PNG_jpg.rf.9810e08f2b7c4a491fd939bbf01272d1.jpg -> 640 x 640
# cnt537-3024x4032-241312131_jpg.rf.a97f46059867c6f10644f7988fd86953.jpg -> 1024 x 1024
# 40_PNG_jpg.rf.4ffea2b75ca94439158f109e1982e85b.jpg -> 640 x 640
# cnt1000-3024x4032-341222151_jpg.rf.7195969fa215a66cb1ff2a242675a5f4.jpg -> 1024 x 1024
# -5_PNG_jpg.rf.81642c497c70599182448a0a73282b50.jpg -> 640 x 640
# 20_PNG_jpg.rf.a8a36d576e1c3551836c1f814d47cc50.jpg -> 640 x 640
# cnt1245-3024x4032-351312241_jpg.rf.e53644c08543012d2cb0ea8901f03771.jpg -> 1024 x 1024
# cnt1071-3024x4032-331212211_jpg.rf.ffb6627fd5688afb1ce0c382395e3f02.jpg -> 1024 x 1024
# cnt1181-3024x4032-342322131_jpg.rf.c3d436bfe0e9dc97580f2c073c65bbb5.jpg -> 1024 x 1024
# 62_PNG_jpg.rf.1cb0ab96d8022efaede3c59959fb02bf.jpg -> 640 x 640
# 82_PNG_jpg.rf.4d851e0f6d1f67b65f3370cc3106b4ef.jpg -> 640 x 640
# cnt937-3024x4032-341212131_jpg.rf.0bf25055cce2f4265510eeea657c84e4.jpg -> 1024 x 1024
# cnt1106-3024x4032-343312241_jpg.rf.b2b5f8735be9b6ff8d5746ae0f4c5cc5.jpg -> 1024 x 1024
# 57_PNG_jpg.rf.bac469b56d3ea85841017072859ac2ee.jpg -> 640 x 640
# cnt1053-3024x4032-341212131_jpg.rf.4fb31cee7a0ced7e6bba95832c703359.jpg -> 1024 x 1024
# 85_PNG_jpg.rf.1a44c031ab2ab446744ea77f143b0d17.jpg -> 640 x 640
# cnt1494-3024x4032-342322231_jpg.rf.b842476e1aefc40b18178127b9af39cc.jpg -> 1024 x 1024
# cnt1527-3024x4032-451212241_jpg.rf.9c99bd430a3bbe0e10c2d0c4fc4be793.jpg -> 1024 x 1024
# 34_PNG_jpg.rf.ff7ce28d539a4c5de23a5e67e27dfce5.jpg -> 640 x 640
# cnt1040-3024x4032-241111111_jpg.rf.59821799ca5ad4bdfd84988414357aa7.jpg -> 1024 x 1024
# 201a5f6f17c216db7800faef8836e125_jpg.rf.0f0879aa2acff05195d8f7fe472484a4.jpg -> 640 x 640
ProtectWyJQcm90ZWN0Il0_FocusFillWzI5NCwyMjIsIngiLDFd_jpeg_jpg.rf.a91386b42abbfbe08c9bcf0cc6577e23.jpg -> 640 x 640
# pig40_0_917_jpeg.rf.046369ec5ef875af1814b41c358b7b15.jpg -> 640 x 640
# IMG_3747_0_6493_jpeg.rf.e0a50af056d41152a304e9b207bc23bd.jpg -> 640 x 640
# melasma31_0_2558_jpeg.rf.d77acc102bbbb85dab9051541d3a491d.jpg -> 640 x 640
# IMG_4639_jpg.rf.a3ed5e9b5c676564a8aac3fbddf009cc.jpg -> 640 x 640
# yt-false-0017_jpg.rf.602d19e0a7621af9abf0cde3ea36ef4d.jpg -> 640 x 640
# 104_jpg.rf.01f84ed22421b99a97c5000a5325b020.jpg -> 640 x 640
# 6_0_4389_jpeg.rf.9650bea88928eb91c138b6cacec1b545.jpg -> 640 x 640
# 9_0_1101_jpeg.rf.28e9bf519c395d289ef9d6f39fd0554e.jpg -> 640 x 640
# image_35_jpg.rf.0af3b8c1c0e30ea647f6153f241e10d3.jpg -> 640 x 640
# 3144__ProtectWyJQcm90ZWN0Il0_FocusFillWzI5NCwyMjIsIngiLDFd_jpeg_jpg.rf.5df6a45f3e817de857c5f03b6f1a5796.jpg -> 640 x 640
# pigmentation-dark-spots_50_jpg.rf.917dc142b73076b8e0bb21e84547eeb0.jpg -> 640 x 640
# yt-LrMrhZhlHyU-0651_jpg.rf.07d491eb6a9846a12db547d714487993.jpg -> 640 x 640
# 18_0_8685_jpeg.rf.7d1b62957c6419637e859e6fc3e28852.jpg -> 640 x 640
# Age-Spots_jpeg_jpg.rf.f0614b9a832d81b5064db7fd714c6ea3.jpg -> 640 x 640
# IMG_2984_0_1872_jpeg.rf.7016bee9c2054f85a17f1433960f9513.jpg -> 640 x 640
# images-23-_jpeg.rf.97dc0f2f20f54e3ca4c078a066a1cfdd.jpg -> 640 x 640
# image_39_jpg.rf.67e847fae579f6e573242fa683daeef5.jpg -> 640 x 640
# pig11_0_2028_jpeg.rf.adbbfb469b70b4b8bdcea411a723421e.jpg -> 640 x 640
# pig44_0_8213_jpeg.rf.33937af61a4be662fc4fd36cb1d849ef.jpg -> 640 x 640
# IMG_2930_0_7535_jpeg.rf.40294423f50f59f8a50013e7140d7302.jpg -> 640 x 640
# th-7-_jpeg.rf.d238a1b3802858fcd2347dd51b368856.jpg -> 640 x 640
# images-1-copy_jpeg_0_4801_jpeg.rf.f050d8ff47967ef7c2a81b9ab9a5fb11.jpg -> 640 x 640
# IMG_4618_jpg.rf.9086064acb5f1b1ad87d84a8745fa838.jpg -> 640 x 640
# melasma27_jpg.rf.0cf2c470089eeb7cfb1bc875dd860a69.jpg -> 640 x 640
# IMG_4644_jpg.rf.9432359c515973a3e1f93e246bdecce1.jpg -> 640 x 640
# pig17_0_8535_jpeg.rf.cbec32b46ca42fc0e177fa33b739d81e.jpg -> 640 x 640
# IMG_2928_0_1489_jpeg.rf.d73e095b6958a4d9da7448e8c6bfb69d.jpg -> 640 x 640
# 103_jpg.rf.6178ea42d36a0454ca812bc1ce50537c.jpg -> 640 x 640
# pig56_0_8786_jpeg.rf.26371584d08865566cae535861b9e449.jpg -> 640 x 640
# melasma4_0_8486_jpeg.rf.b0201ca14c9a12058e4f7affafaca98f.jpg -> 640 x 640
# pig30_0_7118_jpeg.rf.27172dd0a7d4ffc2973802a5f1f006c4.jpg -> 640 x 640
# th-22-_jpeg.rf.7dbbbc5f3d84fa4cf013c87ebbbc7536.jpg -> 640 x 640
# pig34_0_8678_jpeg.rf.40bd21357a3c3133033ba533efc9e093.jpg -> 640 x 640
# pigmentation_dark_spots_14_jpg.rf.52c2c1b0d4ad00060137cb29a7059997.jpg -> 640 x 640
# IMG_2958_0_8441_jpeg.rf.664d0e881584c244875af49ffa3318f7.jpg -> 640 x 640
# IMG_2984_jpg.rf.7f57357aa990c5f3b5cb229479f98e28.jpg -> 640 x 640
# images-36-_jpeg.rf.7bb2ee7eb4b7ce3c50d75930930fa985.jpg -> 640 x 640
# melasma4_jpg.rf.20fc67d7da4365fb090a839f425f76c3.jpg -> 640 x 640
# IMG_2955_jpg.rf.4ec0120ef381ca20fd5648ceab4c76a9.jpg -> 640 x 640
# 5_0_2669_jpeg.rf.8526e6cacd566b4fdc93356962a9c207.jpg -> 640 x 640
# pig40_0_6069_jpeg.rf.7a1a2724016c1c5994c5aa0e93bf85c2.jpg -> 640 x 640
# IMG_4644_jpg.rf.3d397d738dc6196df69c3fbec6eb6177.jpg -> 640 x 640
# Total Images: 4286

# %%
from PIL import Image
import os

corrupted = []

for cls in os.listdir(dataset_path):

    folder = os.path.join(dataset_path, cls)

    for img_name in os.listdir(folder):

        img_path = os.path.join(folder, img_name)

        try:
            img = Image.open(img_path)
            img.verify()

        except:
            corrupted.append(img_path)

print("Total Corrupted Images:", len(corrupted))
# Out:
# Total Corrupted Images: 3

# %%
for img in corrupted:
    print(img)
# Out:
# /content/dataset/dataset/inflammatory acne/inflammatory acne-20260612T152239Z-3-001.zip
# /content/dataset/dataset/non inflammatory acne black heads/desktop.ini
# /content/dataset/dataset/pigmentation/_classes.csv

# %%
import os

image_extensions = (".jpg", ".jpeg", ".png", ".bmp", ".tif", ".tiff", ".webp")

total_images = 0
non_image_files = []

for cls in os.listdir(dataset_path):
    folder = os.path.join(dataset_path, cls)

    for file in os.listdir(folder):

        if file.lower().endswith(image_extensions):
            total_images += 1
        else:
            non_image_files.append(os.path.join(folder, file))

print("Total Image Files:", total_images)
print("Total Non-Image Files:", len(non_image_files))
# Out:
# Total Image Files: 4286
# Total Non-Image Files: 3

# %%
# !pip install opencv-python
# Out:
# Requirement already satisfied: opencv-python in /usr/local/lib/python3.12/dist-packages (4.13.0.92)
# Requirement already satisfied: numpy>=2 in /usr/local/lib/python3.12/dist-packages (from opencv-python) (2.0.2)

# %%
import cv2
import os

blur_images = []

threshold = 100

image_extensions = (".jpg", ".jpeg", ".png", ".bmp", ".tif", ".tiff", ".webp")

for cls in os.listdir(dataset_path):

    folder = os.path.join(dataset_path, cls)

    for file in os.listdir(folder):

        if not file.lower().endswith(image_extensions):
            continue

        img_path = os.path.join(folder, file)

        img = cv2.imread(img_path)

        if img is None:
            continue

        gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

        blur_score = cv2.Laplacian(gray, cv2.CV_64F).var()

        if blur_score < threshold:
            blur_images.append((img_path, blur_score))

print("Blur Images Found:", len(blur_images))

# %%
import matplotlib.pyplot as plt
from PIL import Image

for i, (img_path, score) in enumerate(blur_images[:20]):

    plt.figure(figsize=(3,3))
    img = Image.open(img_path)

    plt.imshow(img)
    plt.title(f"Blur Score: {score:.2f}")
    plt.axis("off")
    plt.show()

# %%
threshold = 30

# %%
threshold = 30

# %%
# !pip install imagehash

# %%
from PIL import Image
import imagehash
import os

hashes = {}
duplicates = []

image_extensions = (".jpg", ".jpeg", ".png", ".bmp", ".tif", ".tiff", ".webp")

for cls in os.listdir(dataset_path):

    folder = os.path.join(dataset_path, cls)

    for file in os.listdir(folder):

        if not file.lower().endswith(image_extensions):
            continue

        img_path = os.path.join(folder, file)

        try:
            img = Image.open(img_path)

            h = imagehash.average_hash(img)

            if h in hashes:
                duplicates.append((img_path, hashes[h]))
            else:
                hashes[h] = img_path

        except:
            pass

print("Total Duplicate Images:", len(duplicates))

# %%
print("First 10 Duplicate Pairs:\n")

for i, (dup, original) in enumerate(duplicates[:10]):
    print(f"Duplicate {i+1}")
    print("Original :", original)
    print("Duplicate:", dup)
    print("-"*60)

# %%
import matplotlib.pyplot as plt
from PIL import Image

for i, (dup, original) in enumerate(duplicates[:5]):

    fig, ax = plt.subplots(1, 2, figsize=(8,4))

    ax[0].imshow(Image.open(original))
    ax[0].set_title("Original")
    ax[0].axis("off")

    ax[1].imshow(Image.open(dup))
    ax[1].set_title("Duplicate")
    ax[1].axis("off")

    plt.show()

# %%
from PIL import Image
import numpy as np

exact_duplicates = []

for dup, original in duplicates:

    img1 = np.array(Image.open(original))
    img2 = np.array(Image.open(dup))

    if np.array_equal(img1, img2):
        exact_duplicates.append((dup, original))

print("Exact Duplicate Images:", len(exact_duplicates))

# %%
import shutil
import os

backup_folder = "/content/duplicate_backup"

os.makedirs(backup_folder, exist_ok=True)

for dup, original in exact_duplicates:
    shutil.copy(dup, backup_folder)

print("Backup Completed!")
print("Backup Folder:", backup_folder)

# %%
import os

removed = 0

for dup, original in exact_duplicates:
    os.remove(dup)
    removed += 1

print("Removed Images:", removed)

# %%
import os
import random
import matplotlib.pyplot as plt
from PIL import Image

image_extensions = (".jpg", ".jpeg", ".png", ".bmp", ".webp")

dataset_path = "/content/dataset/dataset"

classes = os.listdir(dataset_path)

for cls in classes:

    folder = os.path.join(dataset_path, cls)

    images = [img for img in os.listdir(folder)
              if img.lower().endswith(image_extensions)]

    sample = random.sample(images, min(30, len(images)))

    plt.figure(figsize=(15,15))

    for i, img in enumerate(sample):

        plt.subplot(5,6,i+1)

        plt.imshow(Image.open(os.path.join(folder, img)))

        plt.title(str(i+1))

        plt.axis("off")

    plt.suptitle(cls, fontsize=18)

    plt.show()

# %%
import os
import random
import matplotlib.pyplot as plt
from PIL import Image

image_extensions = (".jpg", ".jpeg", ".png", ".bmp", ".webp")

classes = os.listdir(dataset_path)

random.seed(42)
sample_images = {}
for cls in classes:

    folder = os.path.join(dataset_path, cls)

    images = [img for img in os.listdir(folder)
              if img.lower().endswith(image_extensions)]

    sample = random.sample(images, min(30, len(images)))
    sample_images[cls] = sample

    plt.figure(figsize=(15,15))

    for i, img in enumerate(sample):

        plt.subplot(5,6,i+1)

        plt.imshow(Image.open(os.path.join(folder, img)))
        plt.title(i+1)
        plt.axis("off")

    plt.suptitle(cls, fontsize=18)
    plt.show()

# %%
import os
import shutil

removed_folder = "/content/Removed_Images"

os.makedirs(removed_folder, exist_ok=True)

print("Folder Ready")

# %%
dataset_path = "/content/drive/MyDrive/Skin Dataset/dataset"

import os
print(os.path.exists(dataset_path))

# %%
import os

print(os.listdir("/content/drive/MyDrive/Skin Dataset"))

# %%
import zipfile
import os

zip_path = "/content/drive/MyDrive/Skin Dataset/dataset-20260709T040035Z-3-001.zip"

extract_path = "/content/dataset"

os.makedirs(extract_path, exist_ok=True)

with zipfile.ZipFile(zip_path, 'r') as zip_ref:
    zip_ref.extractall(extract_path)

print(" Dataset Extracted Successfully")

# %%
import os

print(os.listdir("/content/dataset"))

# %%
print(os.listdir("/content/dataset/dataset"))

# %%
dataset_path = "/content/dataset/dataset"

print(dataset_path)

# %%
import os
import random
import matplotlib.pyplot as plt
from PIL import Image

image_extensions = (".jpg", ".jpeg", ".png", ".bmp", ".webp")

classes = os.listdir(dataset_path)

random.seed(42)

sample_images = {}

for cls in classes:

    folder = os.path.join(dataset_path, cls)

    images = [img for img in os.listdir(folder)
              if img.lower().endswith(image_extensions)]

    sample = random.sample(images, min(30, len(images)))

    sample_images[cls] = sample

    plt.figure(figsize=(15,15))

    for i, img in enumerate(sample):
        plt.subplot(5,6,i+1)
        plt.imshow(Image.open(os.path.join(folder, img)))
        plt.title(i+1)
        plt.axis("off")

    plt.suptitle(cls, fontsize=18)
    plt.show()

# %%
print(sample_images.keys())

# %%
selected = {
    "pores": [6,11,14,19],
    "wrinkles": [],
    "pigmentation": [23,24],
    "Redness": [5,6,7,16,21,30],
    "non inflammatory acne white heads": [28],
    "dark spots": [3,22,29,30],
    "non inflammatory acne black heads": [22],
    "inflammatory acne": []
}

for cls, nums in selected.items():
    print(f"\n===== {cls} =====")

    for n in nums:
        print(n, "->", sample_images[cls][n-1])

# %%
import os
import shutil

removed_folder = "/content/Removed_Images"
os.makedirs(removed_folder, exist_ok=True)

for cls, nums in selected.items():

    class_folder = os.path.join(dataset_path, cls)

    for n in nums:

        filename = sample_images[cls][n-1]

        src = os.path.join(class_folder, filename)

        dst = os.path.join(removed_folder, filename)

        if os.path.exists(src):
            shutil.move(src, dst)
            print("Moved:", filename)

# %%
print("Total removed images:", len(os.listdir(removed_folder)))

# %%
image_extensions = (".jpg", ".jpeg", ".png", ".bmp", ".webp")

for cls in classes:
    folder = os.path.join(dataset_path, cls)

    total = len([
        f for f in os.listdir(folder)
        if f.lower().endswith(image_extensions)
    ])

    print(f"{cls}: {total} images")

# %%
print("Total removed images:", len(os.listdir(removed_folder)))

# %%
import os
import random
import matplotlib.pyplot as plt
from PIL import Image

image_extensions = (".jpg", ".jpeg", ".png", ".bmp", ".webp")

classes = os.listdir(dataset_path)

random.seed(42)

sample_images = {}

for cls in classes:

    folder = os.path.join(dataset_path, cls)

    images = [img for img in os.listdir(folder)
              if img.lower().endswith(image_extensions)]

    sample = random.sample(images, min(30, len(images)))

    sample_images[cls] = sample

    plt.figure(figsize=(15,15))

    for i, img in enumerate(sample):
        plt.subplot(5,6,i+1)
        plt.imshow(Image.open(os.path.join(folder, img)))
        plt.title(i+1)
        plt.axis("off")

    plt.suptitle(cls)
    plt.show()

# %%
for cls, nums in selected.items():
    print(f"\n===== {cls} =====")

    for n in nums:
        print(n, "->", sample_images[cls][n-1])

# %%
print(len(duplicates))

# %%
import os
import shutil

duplicate_folder = "/content/Removed_Images/Duplicates"
os.makedirs(duplicate_folder, exist_ok=True)

moved = 0

for original, duplicate in duplicates:

    if os.path.exists(duplicate):

        filename = os.path.basename(duplicate)

        dst = os.path.join(duplicate_folder, filename)

        shutil.move(duplicate, dst)

        moved += 1

print("Total duplicate images moved:", moved)

# %%
image_extensions = (".jpg", ".jpeg", ".png", ".bmp", ".webp")

for cls in classes:
    folder = os.path.join(dataset_path, cls)

    total = len([
        f for f in os.listdir(folder)
        if f.lower().endswith(image_extensions)
    ])

    print(f"{cls}: {total} images")

# %%
import cv2
import os

image_extensions = (".jpg", ".jpeg", ".png", ".bmp", ".webp")

blur_images = []

threshold = 30   # Blur threshold

for cls in classes:

    folder = os.path.join(dataset_path, cls)

    for img in os.listdir(folder):

        if img.lower().endswith(image_extensions):

            path = os.path.join(folder, img)

            image = cv2.imread(path)

            gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

            score = cv2.Laplacian(gray, cv2.CV_64F).var()

            if score < threshold:
                blur_images.append(path)

print("Blur Images:", len(blur_images))

# %%
import cv2
import numpy as np
import os

image_extensions = (".jpg", ".jpeg", ".png", ".bmp", ".webp")

dark_images = []

threshold = 40

for cls in classes:

    folder = os.path.join(dataset_path, cls)

    for img in os.listdir(folder):

        if img.lower().endswith(image_extensions):

            path = os.path.join(folder, img)

            image = cv2.imread(path)

            gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

            brightness = np.mean(gray)

            if brightness < threshold:
                dark_images.append(path)

print("Dark Images:", len(dark_images))

# %%
import matplotlib.pyplot as plt
from PIL import Image
import random

random.seed(42)

sample_dark = random.sample(dark_images, min(30, len(dark_images)))

plt.figure(figsize=(15,15))

for i, img in enumerate(sample_dark):
    plt.subplot(5,6,i+1)
    plt.imshow(Image.open(img))
    plt.title(i+1)
    plt.axis("off")

plt.show()

# %%
import cv2
import numpy as np
import os

image_extensions = (".jpg", ".jpeg", ".png", ".bmp", ".webp")

bright_images = []

threshold = 220   # Brightness threshold

for cls in classes:

    folder = os.path.join(dataset_path, cls)

    for img in os.listdir(folder):

        if img.lower().endswith(image_extensions):

            path = os.path.join(folder, img)

            image = cv2.imread(path)

            gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

            brightness = np.mean(gray)

            if brightness > threshold:
                bright_images.append(path)

print("Bright Images:", len(bright_images))

# %%
import matplotlib.pyplot as plt
from PIL import Image

plt.figure(figsize=(12,8))

for i, img in enumerate(bright_images):
    plt.subplot(2,4,i+1)
    plt.imshow(Image.open(img))
    plt.title(i+1)
    plt.axis("off")

plt.show()

# %%
remove_bright = [2, 4, 5, 6]

for n in remove_bright:
    print(n, "->", bright_images[n-1])

# %%
import os
import shutil

bright_folder = "/content/Removed_Images/Bright"
os.makedirs(bright_folder, exist_ok=True)

remove_bright = [2, 4, 5, 6]

for n in remove_bright:

    src = bright_images[n-1]

    filename = os.path.basename(src)

    dst = os.path.join(bright_folder, filename)

    if os.path.exists(src):
        shutil.move(src, dst)
        print("Moved:", filename)

# %%
print("Bright images removed:", len(os.listdir(bright_folder)))

# %%
image_extensions = (".jpg", ".jpeg", ".png", ".bmp", ".webp")

print("Final Dataset Summary\n")

for cls in sorted(classes):
    folder = os.path.join(dataset_path, cls)

    total = len([
        f for f in os.listdir(folder)
        if f.lower().endswith(image_extensions)
    ])

    print(f"{cls}: {total} images")

# %%
import shutil

source = "/content/dataset/dataset"
destination = "/content/drive/MyDrive/Cleaned_Dataset"

shutil.copytree(source, destination, dirs_exist_ok=True)

print(" Cleaned Dataset Saved to Google Drive")

# %%
import os

dataset_path = "/content/drive/MyDrive/Cleaned_Dataset"

print(os.path.exists(dataset_path))

# %%
classes = os.listdir(dataset_path)

print(classes)

# %%
import os

image_extensions = (".jpg", ".jpeg", ".png", ".bmp", ".webp")

for cls in classes:
    folder = os.path.join(dataset_path, cls)

    total = len([
        f for f in os.listdir(folder)
        if f.lower().endswith(image_extensions)
    ])

    print(cls, total)
